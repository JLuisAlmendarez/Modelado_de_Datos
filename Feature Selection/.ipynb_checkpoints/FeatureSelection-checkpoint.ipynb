# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://http2.mlstatic.com/D_NQ_NP_2X_960089-MLM26807621582_022018-F.webp" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Data modelling lab </font>
# - <Strong> Teacher: Sara Eugenia Rodríguez </Strong>
# - <Strong> Year </Strong>: 2023
#
#
#
# ### <font color= #2E9AFE> Feature selection</font>

# %% [markdown]
# Feature selection is a process where features that impact the most are automatically selected
#
#
# Irrelevant features migth negativelly affect the model
#
# Benefits:
# - Reduce overfitting
# - Model is easier to understand
# - Reduce training time
#
#
# **Types of feature selection**
#
#
#     - **Wrappers**: Different feature combinations are prepared, tested and evaluated when creating a model with those
#
#         -   Example: RFE
#
#     - **Filtering methods**: This method apply an statistic measure to assign a score to each feature. Features are ranked based on the score
#         - Examples: Variances, correlation, Squared chi, L-Anova
#
#
#     - **Embeed methods** The model itself based let us know most important features
#         - Example: LASSO, RIDGE, Elastic Net, Trees
#
# <img src="https://machinelearningmastery.com/wp-content/uploads/2019/11/Overview-of-Feature-Selection-Techniques3.png" width="550" height="480" align="center"/>

# %% [markdown]
# **Most common techniques**
#
# - Null values percentage
# - Variance amount
# - Pair correlation
# - Multicolinearity
# - PCA
# - Correlation with target value
# - Forward selection
# - Stepwise selection
# - LASSO
# - Tree based selection

# %% [markdown]
# #### Datos: Glass Identification Data Set
# Data can be found :
# https://archive.ics.uci.edu/ml/datasets/glass+identification
#
# Se busca identificar qué tipo de vidrio es una muestra.
# We want to identify which glass type is each sample
#
#
# - 1. Id number: 1 a 214
# - 2. RI: Refractive index
# - 3. Na: Sodium
# - 4. Mg: Magneisum
# - 5. Al: Aliminium
# - 6. Si: Silicon
# - 7. K: Potasium
# - 8. Ca: Calcium
# - 9. Ba: Barium
# - 10. Fe: Iron
# - 11. Glass type:

# %%
#Import libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load glass data
data = pd.read_csv('glass.data',header=None)
names = ['ID','refraction_index','Na','Mg','Al','Si','K', 'Ca','Ba','Fe','Tipo_Vidrio']
data.columns = names

# %%
data.head()
# Out:
#    ID  refraction_index     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1           1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2           1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3           1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4           1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5           1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# # Filtering methods

# %% [markdown]
# ### Eliminating features with ccertain % of null values
#
# 1. Take out variables that have a high % of null values

# %% [markdown]
# ## Correlation between pairs criteria (without takink in consideration target variable)
#
# $$y=\beta_{0}+\beta_{1}X_{1}+\beta_{2}X_{2}+...+\epsilon$$
#
#
# when there is correlation between 2 predictors, we can't determine the efect from 1 variable,because both variables change together
#
# So, when we have correlation between 2 predictors we can consider that each one give us the same information to the model, So it's prefferable to chosse features that are not correlatied and avoid "duplicated" data
#
# If 2 variables are strongly correlated , we can keep just one and reduce dimensionality without losing lot of information

# %%
#Split X and Y
X = data.iloc[:,1:10]
Y = data.iloc[:,10]
co= round(X.corr(),2)
co.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_fc360_row0_col0, #T_fc360_row1_col1, #T_fc360_row2_col2, #T_fc360_row3_col3, #T_fc360_row4_col4, #T_fc360_row5_col5, #T_fc360_row6_col6, #T_fc360_row7_col7, #T_fc360_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_fc360_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col4, #T_fc360_row1_col8, #T_fc360_row2_col3, #T_fc360_row2_col6, #T_fc360_row2_col7, #T_fc360_row4_col0, #T_fc360_row6_col1, #T_fc360_row6_col5, #T_fc360_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_fc360_row0_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_fc360_row0_col8, #T_fc360_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_fc360_row1_col0, #T_fc360_row5_col4, #T_fc360_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_fc360_row1_col2, #T_fc360_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_fc360_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_fc360_row1_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_fc360_row1_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_fc360_row1_col7, #T_fc360_row5_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_fc360_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_fc360_row2_col1, #T_fc360_row5_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_fc360_row2_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_fc360_row2_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_fc360_row2_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_fc360_row3_col0, #T_fc360_row5_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_fc360_row3_col1, #T_fc360_row3_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_fc360_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_fc360_row3_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_fc360_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_fc360_row3_col7, #T_fc360_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_fc360_row3_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_fc360_row4_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_fc360_row4_col2, #T_fc360_row6_col4, #T_fc360_row7_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_fc360_row4_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fc360_row4_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_fc360_row4_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_fc360_row4_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_fc360_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_fc360_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_fc360_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_fc360_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_fc360_row5_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_fc360_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_fc360_row6_col2, #T_fc360_row8_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_fc360_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_fc360_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_fc360_row6_col8, #T_fc360_row8_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_fc360_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_fc360_row7_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_fc360_row7_col4, #T_fc360_row8_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_fc360_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_fc360_row8_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_fc360_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_fc360_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_fc360_row8_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# </style>
# <table id="T_fc360">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc360_level0_col0" class="col_heading level0 col0" >refraction_index</th>
#       <th id="T_fc360_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_fc360_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_fc360_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_fc360_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_fc360_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_fc360_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_fc360_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_fc360_level0_col8" class="col_heading level0 col8" >Fe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc360_level0_row0" class="row_heading level0 row0" >refraction_index</th>
#       <td id="T_fc360_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fc360_row0_col1" class="data row0 col1" >-0.190000</td>
#       <td id="T_fc360_row0_col2" class="data row0 col2" >-0.120000</td>
#       <td id="T_fc360_row0_col3" class="data row0 col3" >-0.410000</td>
#       <td id="T_fc360_row0_col4" class="data row0 col4" >-0.540000</td>
#       <td id="T_fc360_row0_col5" class="data row0 col5" >-0.290000</td>
#       <td id="T_fc360_row0_col6" class="data row0 col6" >0.810000</td>
#       <td id="T_fc360_row0_col7" class="data row0 col7" >-0.000000</td>
#       <td id="T_fc360_row0_col8" class="data row0 col8" >0.140000</td>
#     </tr>
#     <tr>
#       <th id="T_fc360_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_fc360_row1_col0" class="data row1 col0" >-0.190000</td>
#       <td id="T_fc360_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fc360_row1_col2" class="data row1 col2" >-0.270000</td>
#       <td id="T_fc360_row1_col3" class="data row1 col3" >0.160000</td>
#       <td id="T_fc360_row1_col4" class="data row1 col4" >-0.070000</td>
#       <td id="T_fc360_row1_col5" class="data row1 col5" >-0.270000</td>
#       <td id="T_fc360_row1_col6" class="data row1 col6" >-0.280000</td>
#       <td id="T_fc360_row1_col7" class="data row1 col7" >0.330000</td>
#       <td id="T_fc360_row1_col8" class="data row1 col8" >-0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_fc360_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_fc360_row2_col0" class="data row2 col0" >-0.120000</td>
#       <td id="T_fc360_row2_col1" class="data row2 col1" >-0.270000</td>
#       <td id="T_fc360_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fc360_row2_col3" class="data row2 col3" >-0.480000</td>
#       <td id="T_fc360_row2_col4" class="data row2 col4" >-0.170000</td>
#       <td id="T_fc360_row2_col5" class="data row2 col5" >0.010000</td>
#       <td id="T_fc360_row2_col6" class="data row2 col6" >-0.440000</td>
#       <td id="T_fc360_row2_col7" class="data row2 col7" >-0.490000</td>
#       <td id="T_fc360_row2_col8" class="data row2 col8" >0.080000</td>
#     </tr>
#     <tr>
#       <th id="T_fc360_level0_row3" class="row_heading level0 row3" >Al</th>
#       <td id="T_fc360_row3_col0" class="data row3 col0" >-0.410000</td>
#       <td id="T_fc360_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_fc360_row3_col2" class="data row3 col2" >-0.480000</td>
#       <td id="T_fc360_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fc360_row3_col4" class="data row3 col4" >-0.010000</td>
#       <td id="T_fc360_row3_col5" class="data row3 col5" >0.330000</td>
#       <td id="T_fc360_row3_col6" class="data row3 col6" >-0.260000</td>
#       <td id="T_fc360_row3_col7" class="data row3 col7" >0.480000</td>
#       <td id="T_fc360_row3_col8" class="data row3 col8" >-0.070000</td>
#     </tr>
#     <tr>

# %%
def calcDrop(res):
    # Obtener todas las variables con una correlacion  > 0.6
    all_corr_vars = list(set(res['v1'].tolist() + res['v2'].tolist()))
    
    # Todas las variables únicas en las columnas a remover
    poss_drop = list(set(res['drop'].tolist()))

    # Quedarse con las variables que no estén en las variables a remover
    keep = list(set(all_corr_vars).difference(set(poss_drop)))
     
    p = res[ res['v1'].isin(keep)  | res['v2'].isin(keep) ][['v1', 'v2']]
    q = list(set(p['v1'].tolist() + p['v2'].tolist()))
    drop = (list(set(q).difference(set(keep))))

    poss_drop = list(set(poss_drop).difference(set(drop)))
    
    m = res[ res['v1'].isin(poss_drop)  | res['v2'].isin(poss_drop) ][['v1', 'v2','drop']]
        
    more_drop = set(list(m[~m['v1'].isin(drop) & ~m['v2'].isin(drop)]['drop']))
    for item in more_drop:
        drop.append(item)
         
    return drop

def corrX_new(df, cut=0.6):
    corr_mtx = df.corr().abs()
    avg_corr = corr_mtx.mean(axis=1)
    up = corr_mtx.where(np.triu(np.ones(corr_mtx.shape), k=1).astype(bool))

    dropcols = list()

    res = pd.DataFrame(columns=(['v1', 'v2', 'v1.target', 'v2.target', 'corr', 'drop']))

    for row in range(len(up) - 1):
        col_idx = row + 1
    for col in range(col_idx, len(up)):
        if corr_mtx.iloc[row, col] > cut:
            if avg_corr.iloc[row] > avg_corr.iloc[col]:
                dropcols.append(row)
                drop = corr_mtx.columns[row]
            else:
                dropcols.append(col)
                drop = corr_mtx.columns[col]

            s = pd.Series([corr_mtx.index[row],
                           up.columns[col],
                           avg_corr[row],
                           avg_corr[col],
                           up.iloc[row, col],
                           drop],
                          index=res.columns)

            res = pd.concat([res, s.to_frame().T], ignore_index=True)


    dropcols_names = calcDrop(res)

    return dropcols_names


drop = corrX_new(X)
print(drop)
# Out:
# []

# %% [markdown]
# Only variable we can remoe is calcium

# %%
X_no_corr = X.drop(columns=['Ca'], axis=1)

# %%
co= X_no_corr.corr()
co.style.background_gradient(cmap='coolwarm').format(precision=1)
# Out:
# <style type="text/css">
# #T_7836c_row0_col0, #T_7836c_row1_col1, #T_7836c_row2_col2, #T_7836c_row3_col3, #T_7836c_row4_col4, #T_7836c_row5_col5, #T_7836c_row6_col6, #T_7836c_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7836c_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_7836c_row0_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7836c_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7836c_row0_col4, #T_7836c_row0_col5, #T_7836c_row1_col7, #T_7836c_row2_col1, #T_7836c_row2_col3, #T_7836c_row2_col6, #T_7836c_row4_col0, #T_7836c_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7836c_row0_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_7836c_row0_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_7836c_row1_col0, #T_7836c_row2_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7836c_row1_col2, #T_7836c_row6_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7836c_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_7836c_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_7836c_row1_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7836c_row1_col6 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_7836c_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7836c_row2_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7836c_row2_col7, #T_7836c_row4_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7836c_row3_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_7836c_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_7836c_row3_col2, #T_7836c_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7836c_row3_col4, #T_7836c_row6_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7836c_row3_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_7836c_row3_col6, #T_7836c_row6_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_7836c_row3_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_7836c_row4_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_7836c_row4_col2, #T_7836c_row7_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_7836c_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7836c_row4_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7836c_row4_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7836c_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7836c_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7836c_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_7836c_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7836c_row5_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_7836c_row5_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7836c_row6_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7836c_row6_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7836c_row6_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7836c_row7_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_7836c_row7_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7836c_row7_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_7836c_row7_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7836c_row7_col4, #T_7836c_row7_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# </style>
# <table id="T_7836c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7836c_level0_col0" class="col_heading level0 col0" >refraction_index</th>
#       <th id="T_7836c_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_7836c_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_7836c_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_7836c_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_7836c_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_7836c_level0_col6" class="col_heading level0 col6" >Ba</th>
#       <th id="T_7836c_level0_col7" class="col_heading level0 col7" >Fe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7836c_level0_row0" class="row_heading level0 row0" >refraction_index</th>
#       <td id="T_7836c_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_7836c_row0_col1" class="data row0 col1" >-0.2</td>
#       <td id="T_7836c_row0_col2" class="data row0 col2" >-0.1</td>
#       <td id="T_7836c_row0_col3" class="data row0 col3" >-0.4</td>
#       <td id="T_7836c_row0_col4" class="data row0 col4" >-0.5</td>
#       <td id="T_7836c_row0_col5" class="data row0 col5" >-0.3</td>
#       <td id="T_7836c_row0_col6" class="data row0 col6" >-0.0</td>
#       <td id="T_7836c_row0_col7" class="data row0 col7" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_7836c_row1_col0" class="data row1 col0" >-0.2</td>
#       <td id="T_7836c_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_7836c_row1_col2" class="data row1 col2" >-0.3</td>
#       <td id="T_7836c_row1_col3" class="data row1 col3" >0.2</td>
#       <td id="T_7836c_row1_col4" class="data row1 col4" >-0.1</td>
#       <td id="T_7836c_row1_col5" class="data row1 col5" >-0.3</td>
#       <td id="T_7836c_row1_col6" class="data row1 col6" >0.3</td>
#       <td id="T_7836c_row1_col7" class="data row1 col7" >-0.2</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_7836c_row2_col0" class="data row2 col0" >-0.1</td>
#       <td id="T_7836c_row2_col1" class="data row2 col1" >-0.3</td>
#       <td id="T_7836c_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_7836c_row2_col3" class="data row2 col3" >-0.5</td>
#       <td id="T_7836c_row2_col4" class="data row2 col4" >-0.2</td>
#       <td id="T_7836c_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_7836c_row2_col6" class="data row2 col6" >-0.5</td>
#       <td id="T_7836c_row2_col7" class="data row2 col7" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row3" class="row_heading level0 row3" >Al</th>
#       <td id="T_7836c_row3_col0" class="data row3 col0" >-0.4</td>
#       <td id="T_7836c_row3_col1" class="data row3 col1" >0.2</td>
#       <td id="T_7836c_row3_col2" class="data row3 col2" >-0.5</td>
#       <td id="T_7836c_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_7836c_row3_col4" class="data row3 col4" >-0.0</td>
#       <td id="T_7836c_row3_col5" class="data row3 col5" >0.3</td>
#       <td id="T_7836c_row3_col6" class="data row3 col6" >0.5</td>
#       <td id="T_7836c_row3_col7" class="data row3 col7" >-0.1</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row4" class="row_heading level0 row4" >Si</th>
#       <td id="T_7836c_row4_col0" class="data row4 col0" >-0.5</td>
#       <td id="T_7836c_row4_col1" class="data row4 col1" >-0.1</td>
#       <td id="T_7836c_row4_col2" class="data row4 col2" >-0.2</td>
#       <td id="T_7836c_row4_col3" class="data row4 col3" >-0.0</td>
#       <td id="T_7836c_row4_col4" class="data row4 col4" >1.0</td>
#       <td id="T_7836c_row4_col5" class="data row4 col5" >-0.2</td>
#       <td id="T_7836c_row4_col6" class="data row4 col6" >-0.1</td>
#       <td id="T_7836c_row4_col7" class="data row4 col7" >-0.1</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row5" class="row_heading level0 row5" >K</th>
#       <td id="T_7836c_row5_col0" class="data row5 col0" >-0.3</td>
#       <td id="T_7836c_row5_col1" class="data row5 col1" >-0.3</td>
#       <td id="T_7836c_row5_col2" class="data row5 col2" >0.0</td>
#       <td id="T_7836c_row5_col3" class="data row5 col3" >0.3</td>
#       <td id="T_7836c_row5_col4" class="data row5 col4" >-0.2</td>
#       <td id="T_7836c_row5_col5" class="data row5 col5" >1.0</td>
#       <td id="T_7836c_row5_col6" class="data row5 col6" >-0.0</td>
#       <td id="T_7836c_row5_col7" class="data row5 col7" >-0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7836c_level0_row6" class="row_heading level

# %% [markdown]
# There are no longer X variables strongly correlated

# %% [markdown]
# ## Elimination methods taking in consideration X and Y

# %% [markdown]
# ## Correlation with Y criteria
#
# - Eliminar variables que tienen una correlación baja con la variable a predecir
# - Eliminate variales with weak correlation with output variable

# %%
co= data.iloc[:,1:11].corr()
co.style.background_gradient(cmap='coolwarm').format(precision=1)
# Out:
# <style type="text/css">
# #T_b2c1c_row0_col0, #T_b2c1c_row1_col1, #T_b2c1c_row2_col2, #T_b2c1c_row3_col3, #T_b2c1c_row4_col4, #T_b2c1c_row5_col5, #T_b2c1c_row6_col6, #T_b2c1c_row7_col7, #T_b2c1c_row8_col8, #T_b2c1c_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b2c1c_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col4, #T_b2c1c_row1_col8, #T_b2c1c_row2_col1, #T_b2c1c_row2_col3, #T_b2c1c_row2_col6, #T_b2c1c_row2_col7, #T_b2c1c_row2_col9, #T_b2c1c_row4_col0, #T_b2c1c_row6_col1, #T_b2c1c_row6_col5, #T_b2c1c_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_b2c1c_row0_col7, #T_b2c1c_row4_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b2c1c_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b2c1c_row0_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b2c1c_row1_col0, #T_b2c1c_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b2c1c_row1_col2, #T_b2c1c_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b2c1c_row1_col3, #T_b2c1c_row5_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b2c1c_row1_col4, #T_b2c1c_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b2c1c_row1_col5, #T_b2c1c_row9_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b2c1c_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b2c1c_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b2c1c_row1_col9, #T_b2c1c_row9_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_b2c1c_row2_col4, #T_b2c1c_row2_col5, #T_b2c1c_row9_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b2c1c_row2_col8, #T_b2c1c_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b2c1c_row3_col0, #T_b2c1c_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b2c1c_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b2c1c_row3_col2, #T_b2c1c_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b2c1c_row3_col4, #T_b2c1c_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b2c1c_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_b2c1c_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b2c1c_row3_col7, #T_b2c1c_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b2c1c_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b2c1c_row3_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_b2c1c_row4_col1, #T_b2c1c_row4_col6, #T_b2c1c_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b2c1c_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b2c1c_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b2c1c_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b2c1c_row4_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b2c1c_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b2c1c_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_b2c1c_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b2c1c_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b2c1c_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b2c1c_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b2c1c_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_b2c1c_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b2c1c_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b2c1c_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b2c1c_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b2c1c_row6_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b2c1c_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b2c1c_row7_col2, #T_b2c1c_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b2c1c_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b2c1c_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b2c1c_row7_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_b2c1c_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b2c1c_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b2c1c_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_b2c1c_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b2c1c_row8_col4, #T_b2c1c_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_b2c1c_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b2c1c_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_b2c1c_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b2c1c_row9_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b2c1c_row9_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_b2c1c_row9_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b2c1c_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2c1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2c1c_level0_col0" class="col_heading level0 col0" >refraction_index</th>
#       <th id="T_b2c1c_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_b2c1c_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_b2c1c_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_b2c1c_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_b2c1c_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_b2c1c_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_b2c1c_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_b2c1c_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_b2c1c_level0_col9" class="col_heading level0 col9" >Tipo_Vidrio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2c1c_level0_row0" class="row_heading level0 row0" >refraction_index</th>
#       <td id="T_b2c1c_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_b2c1c_row0_col1" class="data row0 col1" >-0.2</td>
#       <td id="T_b2c1c_row0_col2" class="data row0 col2" >-0.1</td>
#       <td id="T_b2c1c_row0_col3" class="data row0 col3" >-0.4</td>
#       <td id="T_b2c1c_row0_col4" class="data row0 col4" >-0.5</td>
#       <td id="T_b2c1c_row0_col5" class="data row0 col5" >-0.3</td>
#       <td id="T_b2c1c_row0_col6" class="data row0 col6" >0.8</td>
#       <td id="T_b2c1c_row0_col7" class="data row0 col7" >-0.0</td>
#       <td id="T_b2c1c_row0_col8" class="data row0 col8" >0.1</td>
#       <td id="T_b2c1c_row0_col9" class="data row0 col9" >-0.2</td>
#     </tr>
#     <tr>
#       <th id="T_b2c1c_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_b2c1c_row1_col0" class="data row1 col0" >-0.2</td>
#       <td id="T_b2c1c_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_b2c1c_row1_col2" class="data row1 col2" >-0.3</td>
#       <td id="T_b2c1c_row1_col3" class="data row1 col3" >0.2</td>
#       <td id="T_b2c1c_row1_col4" class="data row1 col4" >-0.1</td>
#       <td id="T_b2c1c_row1_col5" class="data row1 col5" >-0.3</td>
#       <td id="T_b2c1c_row1_col6" class="data row1 col6" >-0.3</td>
#       <td id="T_b2c1c_row1_col7" class="data row1 col7" >0.3</td>
#       <td id="T_b2c1c_row1_col8" class="data row1 col8" >-0.2</td>
#       <td id="T_b2c1c_row1_col9" class="data row1 col9" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_b2c1c_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_b2c1c_row2_col0" class="data row2 col0" >-0.1</td>
#       <td id="T_b2c1c_row2_col1" class="data row2 col1" >-0.3</td>
#       <td id="T_b2c1c_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_b2c1c_row2_col3" class="data row2 col3" >-0.5</td>
#       <td id="T_b2c1c_row2_col4

# %% [markdown]
# # Wrapping methods

# %% [markdown]
# ### Recursive feature elimination
#
# Works by recursively eliminating attributes and building models with attributes that are left
# It uses model accuracy to identify which attributes combination contributes the most to predict the object
# We're going to uses logistic regression to select the 4 main features.

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()


rfe = RFE(model)

#Fitting model
fit = rfe.fit(X, Y)
print("# of features: %d" % fit.n_features_)
print("Selected features: %s" % fit.support_)
# Out:
# # of features: 4
# Selected features: [False False  True  True False  True False  True False]
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data.head()
# Out:
#    ID  refraction_index     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1           1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2           1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3           1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4           1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5           1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
X.loc[:, fit.support_]
# Out:
#        Mg    Al     K    Ba
# 0    4.49  1.10  0.06  0.00
# 1    3.60  1.36  0.48  0.00
# 2    3.55  1.54  0.39  0.00
# 3    3.69  1.29  0.57  0.00
# 4    3.62  1.24  0.55  0.00
# ..    ...   ...   ...   ...
# 209  0.00  2.88  0.08  1.06
# 210  0.00  1.99  0.00  1.59
# 211  0.00  2.02  0.00  1.64
# 212  0.00  1.94  0.00  1.57
# 213  0.00  2.08  0.00  1.67
#
# [214 rows x 4 columns]

# %% [markdown]
# RFE choosed the following variablesMg, Al, K, Ba

# %% [markdown]
# # Embeeded methods

# %% [markdown]
# ### Feature selection based on trees
#
# Tree based models like "random forest" already have a feature selection method internally where we know attribute importance

# %%
#Random forest feature imoortance
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier()

#Fit the model
model.fit(X, Y)

importances = pd.DataFrame(data={
    'Attribute':data.iloc[:,1:10].columns, 
    'Importance': model.feature_importances_
})
importances = importances.sort_values(by='Importance', ascending=False)
importances
# Out:
#           Attribute  Importance
# 0  refraction_index    0.158496
# 2                Mg    0.157841
# 3                Al    0.155985
# 6                Ca    0.115641
# 1                Na    0.107664
# 4                Si    0.092489
# 7                Ba    0.091210
# 5                 K    0.080684
# 8                Fe    0.039989

# %% [markdown]
# 4 most aimportant values are Mg, Al, Ca and refraction_index

# %%
plt.bar(x=importances['Attribute'], height=importances['Importance'], color='#087E8B')
plt.title('Attribute importance from coefficients', size=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Least Absolute Shrinkage and Selection Operator (LASSO)
#
# LASSO algorithm has a regularization parameter that penalizes some variables and make them 0

# %%
#Train-test split
X= data.drop(labels=['ID', 'Tipo_Vidrio'], axis=1)
Y= data['Tipo_Vidrio']

# %%
data.head()
# Out:
#    ID  refraction_index     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1           1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2           1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3           1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4           1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5           1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Tipo_Vidrio
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# Most models are benefit from scaling the data

# %%
#Scalling train data
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
##LASSO
from sklearn.feature_selection import SelectFromModel
sel=LogisticRegression(C=1, penalty='l1', solver='liblinear').fit(X,Y) #LASSO  = L1
sel=SelectFromModel(sel, prefit=True) #Feature selection
X_new=sel.transform(X)
X_new.shape
# Out:
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/jluisalmg/anaconda3/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# (214, 8)

# %%
pd.DataFrame(X_new)
# Out:
#          0     1     2      3     4     5     6    7
# 0    13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..     ...   ...   ...    ...   ...   ...   ...  ...
# 209  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 8 columns]

# %%
X.head()
# Out:
#    refraction_index     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0           1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1           1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2           1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3           1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4           1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %% [markdown]
# Model took out refraction_index feature

# %% [markdown]
# ### References:
#
# - Comparison of F-test and mutual information: https://scikit-learn.org/stable/auto_examples/feature_selection/plot_f_test_vs_mi.html#sphx-glr-auto-examples-feature-selection-plot-f-test-vs-mi-py
# - Feature selection: https://scikit-learn.org/stable/modules/feature_selection.html

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Sara E. Rodríguez.
# </footer>
